# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Assignment_1_data.xlsx')
df.head()
# Out:
#    wage  educ  exper  tenure  nonwhite  female
# 0  3.10    11      2       0         0       1
# 1  3.24    12     22       2         0       1
# 2  3.00    11      2       0         0       0
# 3  6.00     8     44      28         0       0
# 4  5.30    12      7       2         0       0

# %% [markdown]
# # Features of graph

# %%
df.columns
# Out:
# Index(['wage', 'educ', 'exper', 'tenure', 'nonwhite', 'female'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   wage      526 non-null    float64
#  1   educ      526 non-null    int64
#  2   exper     526 non-null    int64
#  3   tenure    526 non-null    int64
#  4   nonwhite  526 non-null    int64
#  5   female    526 non-null    int64
# dtypes: float64(1), int64(5)
# memory usage: 24.8 KB

# %%
df
# Out:
#       wage  educ  exper  tenure  nonwhite  female
# 0     3.10    11      2       0         0       1
# 1     3.24    12     22       2         0       1
# 2     3.00    11      2       0         0       0
# 3     6.00     8     44      28         0       0
# 4     5.30    12      7       2         0       0
# ..     ...   ...    ...     ...       ...     ...
# 521  15.00    16     14       2         0       1
# 522   2.27    10      2       0         0       1
# 523   4.67    15     13      18         0       0
# 524  11.56    16      5       1         0       0
# 525   3.50    14      5       4         1       1
#
# [526 rows x 6 columns]

# %% [markdown]
# # Descriptive Analysis

# %%
df.describe()
# Out:
#              wage        educ      exper      tenure    nonwhite      female
# count  526.000000  526.000000  526.00000  526.000000  526.000000  526.000000
# mean     5.896103   12.562738   17.01711    5.104563    0.102662    0.479087
# std      3.693086    2.769022   13.57216    7.224462    0.303805    0.500038
# min      0.530000    0.000000    1.00000    0.000000    0.000000    0.000000
# 25%      3.330000   12.000000    5.00000    0.000000    0.000000    0.000000
# 50%      4.650000   12.000000   13.50000    2.000000    0.000000    0.000000
# 75%      6.880000   14.000000   26.00000    7.000000    0.000000    1.000000
# max     24.980000   18.000000   51.00000   44.000000    1.000000    1.000000

# %% [markdown]
# # Univariate Analysis

# %%
def uni_plot(feature):
    plt.figure(figsize=(4,3))
    plt.boxplot(df[feature], vert=False)  
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.show()

# %% [markdown]
# Scroll for checking univariate relations in below cell

# %%
for col in df.columns:
    uni_plot(col)

# %%
df['nonwhite'] = df['nonwhite'].map({0:'White', 1:'NonWhite'})
df['nonwhite'].value_counts()
# Out:
# White       472
# NonWhite     54
# Name: nonwhite, dtype: int64

# %%
df['female'] = df['female'].map({0:'Male', 1:'Female'})
df['female'].value_counts()
# Out:
# Male      274
# Female    252
# Name: female, dtype: int64

# %%
import random
color_palettes = [
    "deep",
    "muted",
    "bright",
    "pastel",
    "dark",
    "virdis",
    "Set1",
    "Set2",
    "Set3",
    "husl",
    "Blues",
    "Greens",
    "Oranges",
    "Reds",
    "Purples"
]
def bi_plot(feature1, feature2):
    plt.figure(figsize=(4, 3))
    choice = random.choice(color_palettes)
    sns.scatterplot(x=feature1, y=feature2, data=df, palette="choice")
    plt.title(f'Plot of {feature1} vs {feature2}')
    plt.xlabel(feature1)
    plt.ylabel(feature2)
    plt.plot()

# %%
df.columns
# Out:
# Index(['wage', 'educ', 'exper', 'tenure', 'nonwhite', 'female'], dtype='object')

# %% [markdown]
# # Bi-variate Analysis

# %% [markdown]
# Use the scroll bar in below cell to check bi-variate relations

# %%
for i in range(len(df.columns)):
    for j in range(i + 1, len(df.columns)):
        col_i = df.columns[i]
        col_j = df.columns[j]
        if (col_i == 'female' and col_j == 'nonwhite') or (col_i == 'nonwhite' and col_j == 'female'):
            continue
        bi_plot(col_i, col_j);
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5772\1528666508.py:22: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x=feature1, y=feature2, data=df, palette="choice")
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5772\1528666508.py:22: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x=feature1, y=feature2, data=df, palette="choice")
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5772\1528666508.py:22: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x=feature1, y=feature2, data=df, palette="choice")
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5772\1528666508.py:22: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x=feature1, y=feature2, data=df, palette="choice")
# ...
